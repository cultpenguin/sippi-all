# %% [markdown]
# # Training images with Getting started with MPSlib
#
# scikit-mps conrtains a module taht allow loading and creating a number of training images

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpslib as mps
import pyvista 
pyvista.global_theme.jupyter_backend = 'panel'

# %% [markdown]
# ### List the available training images

# %%
TI_type, TI_desc = mps.trainingimages.ti_list()
# Out:
# Available training images:
#    checkerboard - 2D checkerboard
#   checkerboard2 - 2D checkerboard - alternative
#       strebelle - 2D discrete channels from Strebelle
#           lines - 2D discrete lines
#          stones - 2D continious stones
#      bangladesh - 2D discrete Bangladesh
#            maze - 2D discrete maze
#           rot90 - 3D rotation 90
#           rot20 - 3D rotation 20
#        horizons - 3D continious horizons
#         fluvsim - 3D discrete fluvsim

# %%
TI, TI_name = mps.trainingimages.lines()
plt.imshow(TI[:,:,0].T, interpolation='none')

# %%
TI, TI_name = mps.trainingimages.fluvsim()
TI_grid  =mps.plot.numpy_to_pvgrid(TI)
TI_grid.plot(return_viewer=True)
# Out:
# C:\Users\thoma\anaconda3\envs\tf2\lib\site-packages\pyvista\core\dataset.py:1555: PyvistaDeprecationWarning: Use of `cell_arrays` is deprecated. Use `cell_data` instead.
#   warnings.warn(
# VTKRenderWindowSynchronized(vtkWin32OpenGLRenderWindow, color_mappers=[LinearColorMapper(id='102...], orientation_widget=True, sizing_mode='stretch_width')
